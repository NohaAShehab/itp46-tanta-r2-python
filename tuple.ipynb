# %% [markdown]
# # tuples
# - are one of the most popular datatypes in python
# - tuple are immutable datatype -once created cannot be changed-

# %%
t= ()
myt  = tuple()

# %%
myt = ("new", 324, True,( 33.4, None), ['python', 'django'])
print(myt)
# Out:
# ('new', 324, True, (33.4, None), ['python', 'django'])

# %%
print(myt[2])
# Out:
# True

# %%
print(myt[3:5])
# Out:
# ((33.4, None), ['python', 'django'])

# %%
print(myt[4][1])
# Out:
# django

# %%
print(len(myt))
# Out:
# 5

# %%
print(myt.count('new'))
# Out:
# 1

# %%
print(myt.index('new'))
# Out:
# 0

# %%
for item in myt:
    print(item)
# Out:
# new
# 324
# True
# (33.4, None)
# ['python', 'django']

# %%
# concat ?
t1 = ("new", 232, "iti")
t2 = ("python", "django", 'flask', 'fast')

newt = t1 + t2
print(newt)
# Out:
# ('new', 232, 'iti', 'python', 'django', 'flask', 'fast')

# %%
tt = ("python", "django", 'linux')
tt2 = tt  # shallow copy

# %%
print('iti' in myt)
# Out:
# False

# %%
# enumarate

index = 0
for item in tt:
    print(f'{index} - {item}')
    index += 1
# Out:
# 0 - python
# 1 - django
# 2 - linux

# %%
print(enumerate(tt))
# Out:
# <enumerate object at 0x7759ddd61f80>

# %%
for index, item in enumerate(tt):
    print(f'{index} - {item}')
# Out:
# 0 - python
# 1 - django
# 2 - linux

# %%
t5 = (34,23,32, -1)
print(min(t5))
# Out:
# -1

# %%
message = "We love python"
print(tuple(message))
# Out:
# ('W', 'e', ' ', 'l', 'o', 'v', 'e', ' ', 'p', 'y', 't', 'h', 'o', 'n')

# %%
items = ("Python", "django", "Flask", "Fast")

newm = "_".join(items)
print(newm)
# Out:
# Python_django_Flask_Fast

# %%
t1 = ("iti")
print(t1, type(t1))
# Out:
# iti <class 'str'>

# %%
t1 = tuple("iti")
print(t1, type(t1))
# Out:
# ('i', 't', 'i') <class 'tuple'>

# %%
t1 = tuple(["iti"])
print(t1, type(t1))
# Out:
# ('iti',) <class 'tuple'>

# %%
t6= tuple("t")
print(t6 )
# Out:
# ('t',)

# %%
t6 = ("iti", )
print(t6, type(t6) )
# Out:
# ('iti',) <class 'tuple'>
