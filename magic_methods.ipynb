# %%
# I need to allow setting salary ???
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary= salary

emp = Employee("wee", "ee@gmail.com", 2323)

# %%
print(emp)

# %%
# control how the object is represent when you print it ...
""" when try to print the object implementation of __str__ is called ??
if not __str__  overriden ,,, check __repr__ if not ... call the default beh.

    its default behaviour, <class name> object at <address>
    so of u need to change this behaviour ?? override
"""
# I need to allow setting salary ???
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary= salary
    def __str__(self):
        return f"{self.name}"

emp = Employee("wee", "ee@gmail.com", 2323)
print(emp)
# Out:
# wee

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary= salary
    def __repr__(self):
        return f"{self.name}"

emp = Employee("sd", 'weew', 2143)
print(emp)
# Out:
# sd

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary= salary

    def __str__(self):  # must return with str
        return f"{self.name}"
    def __repr__(self): # must return with str
        return f"Employee(name={self.name}, email={self.email}, salary={self.salary})"

emp = Employee("sd", 'weew', 2143)
print(emp)
print(emp.__repr__())
# Out:
# sd
# Employee(name=sd, email=weew, salary=2143)

# %%
l = [4,3,4,3]
print(len(l))
# Out:
# 4

# %%
print(len(emp))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(len(emp))
#
# TypeError: object of type 'Employee' has no len()

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary= salary

    def __str__(self):  # must return with str
        return f"{self.name}"
    def __repr__(self): # must return with str
        return f"Employee(name={self.name}, email={self.email}, salary={self.salary})"

    def __len__(self):
        # must return with int...
        return  3

emp = Employee("sd", 'weew', 2143)
print(len(emp))
# Out:
# 3

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary= salary

    def __str__(self):  # must return with str
        return f"{self.name}"
    def __repr__(self): # must return with str
        return f"Employee(name={self.name}, email={self.email}, salary={self.salary})"

    def __len__(self):
        # must return with int...
        return  len(self.__dict__)

emp = Employee("sd", 'weew', 2143)
emp.city ='cairo'
print(len(emp))
# Out:
# 4

# %%
# call the object
emp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # call the object
# ----> 2 emp()
#
# TypeError: 'Employee' object is not callable

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary= salary

    def __str__(self):  # must return with str
        return f"{self.name}"
    def __repr__(self): # must return with str
        return f"Employee(name={self.name}, email={self.email}, salary={self.salary})"

    def __len__(self):
        # must return with int...
        return  len(self.__dict__)

    def __call__(self, *args, **kwargs):
        print("--- emp object is called ")

emp = Employee("sd", 'weew', 2143)
emp.city ='cairo'
print(len(emp))

emp()
# Out:
# 4
# --- emp object is called

# %%
### make the class only restricted to the properties I define

class Employee:
    __slots__ = ['name', 'email', 'salary']  # disable __dict__
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary= salary


emp = Employee("sd", 'weew', 2143)
emp.city ='cairo'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 12
#       8         self.salary= salary
#       9
#      10
#      11 emp = Employee("sd", 'weew', 2143)
# ---> 12 emp.city ='cairo'
#
# AttributeError: 'Employee' object has no attribute 'city' and no __dict__ for setting new attributes

# %%
# __gt__, __ne__  ((queryset api reference ))
