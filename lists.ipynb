# %% [markdown]
# # lists
# - are the most popular datatype in python
# - list are mutable datatype

# %%
from operator import mul

l= []
myl  = list()

# %%
myl = ["new", 324, True, 33.4, None, ['python', 'django']]
print(myl)
# Out:
# ['new', 324, True, 33.4, None, ['python', 'django']]

# %%
print(myl[2])
# Out:
# True

# %%
print(myl[3:5])
# Out:
# [33.4, None]

# %%
print(myl[5][1])
# Out:
# django

# %%
myl = ["new", 324, True, 33.4, None, ['python', 'django'],
       "iti", "iti", "iti"]

print(len(myl))
# Out:
# 9

# %%
print(myl.count('iti'))
# Out:
# 3

# %%
print(myl.index('iti'))
# Out:
# 6

# %%
for item in myl:
    print(item)
# Out:
# new
# 324
# True
# 33.4
# None
# ['python', 'django']
# iti
# iti
# iti

# %%
# update element at existing index
print(myl)
myl[7] = 'updated'
print(myl)
# Out:
# ['new', 324, True, 33.4, None, ['python', 'django'], 'iti', 'iti', 'iti']
# ['new', 324, True, 33.4, None, ['python', 'django'], 'iti', 'updated', 'iti']

# %%
myl[100] = 'updated'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 myl[100] = 'updated'
#
# IndexError: list assignment index out of range

# %%
# add element to list

myl.append("new element")
print(myl)
# Out:
# ['new', 324, True, 33.4, None, ['python', 'django'], 'iti', 'updated', 'iti', 'new element']

# %%
print(myl)
myl.insert(3, "inserted")
print(myl)
# Out:
# ['new', 324, True, 33.4, None, ['python', 'django'], 'iti', 'updated', 'iti', 'new element']
# ['new', 324, True, 'inserted', 33.4, None, ['python', 'django'], 'iti', 'updated', 'iti', 'new element']

# %%
myl.insert(100, "inserted") # add it to the end of the list
print(myl)
# Out:
# ['new', 324, True, 'inserted', 33.4, None, ['python', 'django'], 'iti', 'updated', 'iti', 'new element', 'inserted']

# %%
# remove elements from list

popped_element = myl.pop()
print(myl)
print(popped_element)
# Out:
# ['new', 324, True, 'inserted', 33.4, None, ['python', 'django'], 'iti', 'updated', 'iti', 'new element']
# inserted

# %%
# pop at index
print(myl)
popped_element = myl.pop(5)
print(myl)
# Out:
# ['new', 324, True, 'inserted', 33.4, None, ['python', 'django'], 'iti', 'updated', 'iti', 'new element']
# ['new', 324, True, 'inserted', 33.4, ['python', 'django'], 'iti', 'updated', 'iti', 'new element']

# %%
print(popped_element)
# Out:
# None

# %%
# if you don't know index, but know element ??
print(myl)
myl.remove('iti') # remove first occurrence
print(myl)
# Out:
# ['new', 324, True, 'inserted', 33.4, ['python', 'django'], 'iti', 'updated', 'iti', 'new element']
# ['new', 324, True, 'inserted', 33.4, ['python', 'django'], 'updated', 'iti', 'new element']

# %%
# concat ?
l1 = ["new", 232, "iti"]
l2 = ["python", "django", 'flask', 'fast']

newl = l1 + l2
print(newl)
# Out:
# ['new', 232, 'iti', 'python', 'django', 'flask', 'fast']

# %%
# extend ?
l1.extend(l2)
print(l1 )
# Out:
# ['new', 232, 'iti', 'python', 'django', 'flask', 'fast']

# %%
# sort in python --> require all elements of list to be from the same type ?
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # sort?
# ----> 3 l1.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
print(l2)
l2.sort()
print(l2)
# Out:
# ['python', 'django', 'flask', 'fast']
# ['django', 'fast', 'flask', 'python']

# %%
l2.sort(reverse=True)
print(l2)
# Out:
# ['python', 'flask', 'fast', 'django']

# %%
ll1 =[]
ll1.extend(l2)
print(ll1)
# Out:
# ['python', 'flask', 'fast', 'django']

# %%
l1 = [23,323, "True"]
l1.append(l2)
print(l1)
# Out:
# [23, 323, 'True', ['python', 'flask', 'fast', 'django']]

# %%
ll = ["python", "django", 'linux']
ll2 = ll  # shallow copy

# %%
ll.append("iti")
print(ll)
print(ll2)
# Out:
# ['python', 'django', 'linux', 'iti']
# ['python', 'django', 'linux', 'iti']

# %%
# deep copy --> create new address in memory

l3 = ll.copy()
print(l3)
# Out:
# ['python', 'django', 'linux', 'iti']

# %%
ll.append("new element")
print(ll)

print(l3)
# Out:
# ['python', 'django', 'linux', 'iti', 'new element']
# ['python', 'django', 'linux', 'iti']

# %%
# reverse a list
print(myl)
# Out:
# ['new', 324, True, 'inserted', 33.4, ['python', 'django'], 'updated', 'iti', 'new element']

# %%
myl.reverse()
print(myl)
# Out:
# ['new element', 'iti', 'updated', ['python', 'django'], 33.4, 'inserted', True, 324, 'new']

# %%
print('iti' in myl)
# Out:
# True

# %%
# enumarate

index = 0
for item in ll:
    print(f'{index} - {item}')
    index += 1
# Out:
# 0 - python
# 1 - django
# 2 - linux
# 3 - iti
# 4 - new element

# %%
print(enumerate(ll))

# %%
for index, item in enumerate(ll):
    print(f'{index} - {item}')
# Out:
# 0 - python
# 1 - django
# 2 - linux
# 3 - iti
# 4 - new element

# %%
l4 =['python', 'django', 'linux', 4, 33,True, 'iti', 'new element']

# %%
l4_enum = enumerate(l4)
print(l4_enum)

# %%
for index, item  in l4_enum:
    print(f'{index} - {item}')
# Out:
# 0 - python
# 1 - django
# 2 - linux
# 3 - 4
# 4 - 33
# 5 - True
# 6 - iti
# 7 - new element

# %%
for index, item  in l4_enum:
    print(f'{index} - {item}')

# %%
for i , t in enumerate(l4):
    print(f'{i} - {t}')
# Out:
# 0 - python
# 1 - django
# 2 - linux
# 3 - 4
# 4 - 33
# 5 - True
# 6 - iti
# 7 - new element

# %%
l5 = [34,23,32, -1]
print(min(l5))
# Out:
# -1

# %%
message = "We love python"
print(list(message))
# Out:
# ['W', 'e', ' ', 'l', 'o', 'v', 'e', ' ', 'p', 'y', 't', 'h', 'o', 'n']

# %%
message = "We love python"
new_message = message.split()
print(new_message)
# Out:
# ['We', 'love', 'python']

# %%
items = ["Python", "django", "Flask", "Fast"]

newm = "_".join(items)
print(newm)
# Out:
# Python_django_Flask_Fast
