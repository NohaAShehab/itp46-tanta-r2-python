# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # change datatype of variable in the runtime ?

# %%
year = 2026 # int
print(type(year))

# convert int to string
year = str(year)
print(year, type(year))
# Out:
# <class 'int'>
# 2026 <class 'str'>

# %%
# convert from string to int ??

num = "100" # numeric string ??
print(type(num))

num =  int(num)
print(type(num))
# Out:
# <class 'str'>
# <class 'int'>

# %%
message = "Hello"
print(type(message))
message = int(message)
print(type(message))
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 message = "Hello"
#       2 print(type(message))
# ----> 3 message = int(message)
#       4 print(type(message))
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# # logical operators

# %%
print("Hello" and "ITI" and 10 )
# Out:
# 10

# %%
print(0 and "iti" and False )
# Out:
# 0

# %%
print("-" and "iti" and "&" )
# Out:
# &

# %%
print("              " and "iti")
# Out:
# iti

# %% [markdown]
# # complex number

# %%
"""
  sqrt -1  ===> i . imaginary part

"""
c = complex(4, 6)
print(c)
# Out:
# (4+6j)

# %%
c2 = 6+ 4j

print(c2)
# Out:
# (6+4j)

# %%
num1 = 32.77
num2 = 32.33

print(round(num1))
print(round(num2))
# Out:
# 33
# 32

# %%
counter = 0
while counter <5 :
    print(counter)
    counter = counter + 1
# Out:
# 0
# 1
# 2
# 3
# 4
