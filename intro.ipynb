# %% [markdown]
# <div align="center" style="padding: 16px; border-radius: 14px; background: linear-gradient(135deg, #ff9a9e, #fad0c4, #fad0c4); border: 2px solid #6a11cb;">
#   <h1 style="margin: 0; color: #2d1b69;">🐍 Python Notebook Illustration</h1>
#   <p style="margin: 8px 0 0 0; color: #3d2c8d;"><b>Learn • Practice • Build</b></p>
#   <p style="margin: 8px 0 0 0; color: #222;">📘 Concepts → 🧪 Examples → ✅ Understanding</p>
# </div>

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This first cell prints a simple message to verify Python execution.</p>
# </div>

# %% [markdown]
# # change datatype of variable in the runtime ?

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This comment cell asks the question of changing variable datatype during runtime.</p>
# </div>

# %%
year = 2026 # int
print(type(year))

# convert int to string
year = str(year)
print(year, type(year))
# Out:
# <class 'int'>
# 2026 <class 'str'>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This demonstrates runtime type conversion from `int` to `str`.</p>
# </div>

# %%
# convert from string to int ??

num = "100" # numeric string ??
print(type(num))

num =  int(num)
print(type(num))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This cell converts a numeric string to an integer using `int()`.</p>
# </div>

# %%
message = "Hello"
print(type(message))
message = int(message)
print(type(message))
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 message = "Hello"
#       2 print(type(message))
# ----> 3 message = int(message)
#       4 print(type(message))
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This example shows conversion failure when a non-numeric string is cast to `int`.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This empty cell can be used for notes before starting logical operator examples.</p>
# </div>

# %% [markdown]
# # logical operators

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This is a heading/comment cell introducing logical operators.</p>
# </div>

# %%
print("Hello" and "ITI" and 10 )
# Out:
# 10

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Another `and` example: the expression returns the final operand when none are falsy.</p>
# </div>

# %%
print(0 and "iti" and False )
# Out:
# 0

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This shows short-circuit behavior: `and` stops at the first falsy operand.</p>
# </div>

# %%
print("-" and "iti" and "&" )
# Out:
# &

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This demonstrates `and` returning the last truthy value when all operands are truthy.</p>
# </div>

# %%
print("              " and "iti")
# Out:
# iti

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This example shows that non-empty strings are truthy in `and` expressions.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This empty cell is available for extra logical operator examples.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This empty cell can be used as a separator before starting a new section.</p>
# </div>

# %% [markdown]
# # complex number

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This is a heading/comment cell introducing the complex number topic.</p>
# </div>

# %%
"""
  sqrt -1  ===> i . imaginary part

"""
c = complex(4, 6)
print(c)
# Out:
# (4+6j)

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This cell introduces complex numbers using Python's `complex(real, imag)` constructor.</p>
# </div>

# %%
c2 = 6+ 4j

print(c2)
# Out:
# (6+4j)

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This cell creates a complex number directly using `a + bj` notation.</p>
# </div>

# %%
num1 = 32.77
num2 = 32.33

print(round(num1))
print(round(num2))
# Out:
# 33
# 32

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This example shows how `round()` handles floating point values.</p>
# </div>

# %%
counter = 0
while counter <5 :
    print(counter)
    counter = counter + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This loop demonstrates repetition with `while` and manual counter updates.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This empty cell can be used to continue practice or add notes for the next concept.</p>
# </div>
