# %% [markdown]
# <div align="center" style="padding: 16px; border-radius: 14px; background: linear-gradient(135deg, #a1c4fd, #c2e9fb); border: 2px solid #2575fc;">
#   <h1 style="margin: 0; color: #0b3c8a;">🔤 String Notebook Illustration</h1>
#   <p style="margin: 8px 0 0 0; color: #1249a1;"><b>Slice • Format • Validate</b></p>
#   <p style="margin: 8px 0 0 0; color: #1d3557;">✂️ Indexing → 🧩 Operations → 🚀 Real Input</p>
# </div>

# %%
iti = "information technology institute"

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This initializes the base string used across all string operation examples.</p>
# </div>

# %%
# 1-get len of string
print(len(iti))
# Out:
# 32

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`len()` gives the total number of characters in a string.</p>
# </div>

# %%
print(iti.count("i"))
# Out:
# 4

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`count()` returns how many times a character appears in the string.</p>
# </div>

# %%
# string is treated like an array
# access string parts using index start from 0
print(iti[4])
# Out:
# r

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Strings behave like sequences, so indexing works similarly to arrays.</p>
# </div>

# %%
print(iti[4:])
# Out:
# rmation technology institute

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This shows index-based access to a single character in a string.</p>
# </div>

# %%
print(iti[4:9])
# Out:
# rmati

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Slicing with only a start index reads from that position to the end.</p>
# </div>

# %%
print(iti[::])
# Out:
# information technology institute

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Slicing with start and end extracts a substring range.</p>
# </div>

# %%
print(iti[::2])
# Out:
# ifraintcnlg nttt

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Full slicing returns a copy-like view of the whole string.</p>
# </div>

# %%
print(iti[::-1])
# Out:
# etutitsni ygolonhcet noitamrofni

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Step slicing with `2` takes every second character.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Negative step slicing `[::-1]` reverses a string.</p>
# </div>

# %% [markdown]
# String is immutable datatype , once created cannot be changed

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This empty cell can separate slicing examples from mutation/formatting topics.</p>
# </div>

# %%
first_name = 'Ahmed'
last_name = 'Ali'
full_name = first_name + " "+ last_name # new string
print(full_name)
# Out:
# Ahmed Ali

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This note highlights that strings are immutable after creation.</p>
# </div>

# %%
print(full_name.upper())
# Out:
# AHMED ALI

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Concatenation produces a new string without mutating the originals.</p>
# </div>

# %%
print(full_name.title())
# Out:
# Ahmed Ali

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`.upper()` returns an uppercase version of the original string.</p>
# </div>

# %%
print(full_name.lower()) # NEW STRING
print(full_name.capitalize())
# Out:
# ahmed ali
# Ahmed ali

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`.title()` converts each word start to uppercase for display formatting.</p>
# </div>

# %%
# interpolation
anymessage = 'test'

newmessage = anymessage + anymessage + anymessage

print(newmessage)


newmessage2 = anymessage *3
print(newmessage2)
# Out:
# testtesttest
# testtesttest

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This compares `.lower()` and `.capitalize()`, both creating new strings.</p>
# </div>

# %%
# replace

msg = "We love python, python is easy ? "

msg2 = msg.replace("o", "@")
print(msg2)
# Out:
# We l@ve pyth@n, pyth@n is easy ?

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">String multiplication repeats text and can simplify interpolation-like patterns.</p>
# </div>

# %%
msg = "We love python, python is easy ? "

msg2 = msg.replace("o", "@", 2 )
print(msg2)
# Out:
# We l@ve pyth@n, python is easy ?

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This replaces all matching characters and returns a new string.</p>
# </div>

# %%
msg = "We love pythOn, pythOn is easy ? "

msg2 = msg.replace("o", "@" )
print(msg2)
# Out:
# We l@ve pythOn, pythOn is easy ?

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`replace(old, new, count)` limits replacements to the specified number.</p>
# </div>

# %%
# iteration ?? for loop ?

for char in "new string":
    print(char)
# Out:
# n
# e
# w
#
# s
# t
# r
# i
# n
# g

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`replace(old, new)` is case-sensitive, so unmatched case stays unchanged.</p>
# </div>

# %%
anystring = "iti"
print(anystring.index("t"))
# Out:
# 1

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This loop iterates character-by-character over a string.</p>
# </div>

# %%
print(anystring.index("i")) # get index of first occurrence of char.
# Out:
# 0

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This finds the first occurrence position of a character in the string.</p>
# </div>

# %%
message = "hello world"
for c in message:
    print(c, message.index(c))
# Out:
# h 0
# e 1
# l 2
# l 2
# o 4
#   5
# w 6
# o 4
# r 8
# l 2
# d 10

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This demonstrates why `index()` inside a loop returns the first occurrence only.</p>
# </div>

# %%
message = "hello world"
counter = 0
for c in message:
    print(c, counter)
    counter +=1
# Out:
# h 0
# e 1
# l 2
# l 3
# o 4
#   5
# w 6
# o 7
# r 8
# l 9
# d 10

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This loop tracks character positions correctly using a manual counter.</p>
# </div>

# %%
print("i" in "Hello world")
# Out:
# False

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`in` checks membership: this returns false when the character does not exist.</p>
# </div>

# %%
print("i" in "iti")
# Out:
# True

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`in` checks membership: this returns true when the character exists.</p>
# </div>

# %%
# ask user to enter a string ?
message = input("Please enter a message: ") # string
print(message, type(message))

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This calculator repeats the same addition flow to reinforce input conversion.</p>
# </div>

# %%
# calculator ?
num1 = input("Please enter a number: ")
num2 = input("Please enter a number: ")
num1 = int(num1)
num2 = int(num2)
res = num1 + num2
print(res)
# Out:
# 56

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This mini calculator adds two inputs after converting them to integers.</p>
# </div>

# %%
num1 = input("Please enter a number: ")
num2 = input("Please enter a number: ")
num1 = int(num1)
num2 = int(num2)
res = num1 + num2
print(res)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 4
#       2 num2 = input("Please enter a number: ")
#       3 num1 = int(num1)
# ----> 4 num2 = int(num2)
#       5 res = num1 + num2
#       6 print(res)
#
# ValueError: invalid literal for int() with base 10: 'wrer'

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This example shows conversion failure when the user enters non-numeric input.</p>
# </div>

# %%
# you may need to examine string content before conversion ?


num = "100"
print(num.isdigit())
print(num.isnumeric())
# Out:
# True
# True

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This compares `isdigit()` and `isnumeric()` for validating numeric strings.</p>
# </div>

# %%
message = "Hello world"
print(message.isalpha())
# Out:
# False

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`isalpha()` fails if the string includes spaces or non-letter characters.</p>
# </div>

# %%
val = "students16"
print(val.isalnum())
# Out:
# True

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`isalnum()` returns true when text contains only letters and digits.</p>
# </div>

# %%
val2 = ""
print(val2.isspace())
# Out:
# False

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">`isspace()` checks whether a string contains only whitespace characters.</p>
# </div>

# %%
num1 = input("Please enter a number: ")
num2 = input("Please enter a number: ")
if num1.isdigit() and num2.isdigit():
    num1 = int(num1)
    num2 = int(num2)
    res = num1 + num2
    print(res)
else:
    print("----- num1, num2, must be integers ")
# Out:
# ----- num1, num2, must be integers

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This validates user input before numeric conversion to avoid runtime errors.</p>
# </div>

# %%
""" this is a string ? """
# Out:
# ' this is a string ? '

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">Triple quotes can be used to create multiline string literals.</p>
# </div>

# %%
# format string
students = 20
coursename=  "Introduction to Python"

course_info = "We have" + students + "Studying " + coursename
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       2 students = 20
#       3 coursename=  "Introduction to Python"
# ----> 5 course_info = "We have" + students + "Studying " + coursename
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This demonstrates a type error when concatenating a string and integer directly.</p>
# </div>

# %%
# format string
students = 20
coursename=  "Introduction to Python"

course_info = "We have " + str(students) + " students Studying " + coursename
print(course_info)
# Out:
# We have 20 students Studying Introduction to Python

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This fixes string concatenation by converting numeric values to text first.</p>
# </div>

# %%
# define template
temp  = "We have* {} students studying {} *course"
temp1 = "We have {0} students studying {1} course"
print(temp)
print(temp1)
# Out:
# We have* {} students studying {} *course
# We have {0} students studying {1} course

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This introduces two template styles for later string formatting examples.</p>
# </div>

# %%
msg = temp.format(students, coursename)  # new string ?

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This cell fills a string template and stores the result in a new variable.</p>
# </div>

# %%
print(msg)
# Out:
# We have* 20 students studying Introduction to Python *course

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This prints the formatted message generated from the template.</p>
# </div>

# %%
print(temp1.format(students, coursename))
# Out:
# We have 20 students studying Introduction to Python course

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This applies positional placeholders to produce a fully formatted sentence.</p>
# </div>

# %%
temp1 = "We have {1} students studying {2} course"
print(temp1.format(students, coursename))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 temp1 = "We have {1} students studying {2} course"
# ----> 2 print(temp1.format(students, coursename))
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This demonstrates a formatting index error when placeholders exceed provided arguments.</p>
# </div>

# %%
temp1 = "We have {0} students studying {1} course"
print(temp1.format(coursename , students))
# Out:
# We have Introduction to Python students studying 20 course

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This example shows argument order effects when formatting positional placeholders.</p>
# </div>

# %%
# define template using keywords
temp1 = "We have {stds_num} students studying {crs_name} course"
print(temp1.format(crs_name='django', stds_num=2124))
# Out:
# We have 2124 students studying django course

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This uses named placeholders with `format()` for readable template substitution.</p>
# </div>

# %%
# f-format string  --> build string based on existing variables

username = 'noha'
work = 'iti'

info = f"My name is {username}, I works at {work}"
print(info)
# create new string --> based on the username, work
# Out:
# My name is noha, I works at iti

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This cell builds a formatted message cleanly using an f-string.</p>
# </div>

# %%
username = 'noha'
work = 'iti'

info = f"My name is {username_}, I works at {work_}"
print(info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 4
#       1 username = 'noha'
#       2 work = 'iti'
# ----> 4 info = f"My name is {username_}, I works at {work_}"
#       5 print(info)
#
# NameError: name 'username_' is not defined

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This example shows an f-string error when variable names are incorrect.</p>
# </div>

# %%
# Out:
# nh

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This cell output likely comes from an earlier variable slicing/selection experiment.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb, #2575fc); padding: 12px; border-radius: 12px; border: 2px solid #ffd166;">
# <h3 style="color: #ffffff; margin: 0;">✨ Idea</h3>
# <p style="color: #f8f9fa; margin: 8px 0 0 0;">This empty cell is reserved for extending the string lesson.</p>
# </div>
